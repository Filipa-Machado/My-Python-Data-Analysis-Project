# %%
import pandas as pd
import matplotlib as plt
world = pd.read_csv('Data for Python Course/2018-2019 Happiness.csv') # Importing world happiness dataset
airbnb = pd.read_csv('Data for Python Course/airbnb.csv')
salaries = pd.read_csv('Data for Python Course/salaries.csv')
sales = pd.read_csv('Data for Python Course/web_sales.csv')
eth = pd.read_csv('Ethereum Historical Data.csv')

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1502 non-null   object
#  1   Coin      1502 non-null   object
#  2   Price     1502 non-null   float64
#  3   Open      1502 non-null   float64
#  4   High      1502 non-null   float64
#  5   Low       1502 non-null   float64
#  6   Vol.      1502 non-null   object
#  7   Change %  1502 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 94.0+ KB

# %%
eth.index
# Out:
# RangeIndex(start=0, stop=1502, step=1)

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.reset_index()
# Out:
#       index        Date Coin    Price     Open     High      Low     Vol.  \
# 0         0  10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K
# 1         1   9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K
# 2         2   8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K
# 3         3   7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K
# 4         4   6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K
# ...     ...         ...  ...      ...      ...      ...      ...      ...
# 1497   1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M
# 1498   1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M
# 1499   1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M
# 1500   1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M
# 1501   1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M
#
#      Change %
# 0       0.89%
# 1       2.76%
# 2      -0.21%
# 3       2.19%
# 4       3.08%
# ...       ...
# 1497    0.94%
# 1498    0.04%
# 1499    5.56%
# 1500   -2.72%
# 1501    1.19%
#
# [1502 rows x 9 columns]

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_index()
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_values(by='Price', ascending = False)
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 824    8/11/2021  ETH  4808.38  4612.05  4822.97  4612.05  673.21K    4.26%
# 823    9/11/2021  ETH  4731.83  4808.34  4836.69  4715.43  437.41K   -1.59%
# 821   11/11/2021  ETH  4720.87  4633.98  4778.17  4578.66  418.61K    1.87%
# 820   12/11/2021  ETH  4667.31  4720.50  4807.16  4511.96  634.59K   -1.13%
# 819   13/11/2021  ETH  4644.61  4665.76  4705.02  4585.37  290.27K   -0.49%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1420  22/03/2020  ETH   122.41   132.59   136.86   121.37   25.25M   -7.67%
# 1424  18/03/2020  ETH   117.77   115.95   117.91   110.16   25.80M    1.47%
# 1425  17/03/2020  ETH   116.06   111.06   120.60   109.67   27.09M    4.54%
# 1426  16/03/2020  ETH   111.02   124.35   124.38   102.44   40.25M  -10.72%
# 1430  12/03/2020  ETH   107.90   194.57   195.40   102.83   53.51M  -44.55%
#
# [1502 rows x 8 columns]

# %%
salaries.sort_values(by = 'salary_in_usd', ascending = False)
# Out:
#       work_year experience_level employment_type  \
# 44         2023               EN              FL
# 8587       2020               MI              FT
# 7099       2022               MI              FT
# 5099       2023               MI              FT
# 8797       2021               MI              FT
# ...         ...              ...             ...
# 3332       2023               MI              FT
# 8207       2022               EN              FT
# 3071       2022               MI              FT
# 7910       2021               EN              FT
# 5282       2020               EX              FT
#
#                                job_title  salary salary_currency  \
# 44      Business Intelligence Consultant  500000             GBP
# 8587                  Research Scientist  450000             USD
# 7099                        Data Analyst  350000             GBP
# 5099                  Analytics Engineer  350000             GBP
# 8797  Applied Machine Learning Scientist  423000             USD
# ...                                  ...     ...             ...
# 3332                        Data Analyst  866000             PHP
# 8207                        Data Analyst   15000             USD
# 3071     Business Intelligence Developer   15000             USD
# 7910          Machine Learning Developer   15000             USD
# 5282                  Staff Data Analyst   15000             USD
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# 44           615201                 IN           100               IN
# 8587         450000                 US             0               US
# 7099         430967                 GB             0               GB
# 5099         430640                 GB             0               GB
# 8797         423000                 US            50               US
# ...             ...                ...           ...              ...
# 3332          15680                 PH            50               PH
# 8207          15000                 ID             0               ID
# 3071          15000                 GH           100               GH
# 7910          15000                 TH           100               TH
# 5282          15000                 NG             0               CA
#
#      company_size
# 44              S
# 8587            M
# 7099            M
# 5099            M
# 8797            L
# ...           ...
# 3332            L
# 8207            L
# 3071            M
# 7910            L
# 5282            M
#
# [8805 rows x 11 columns]

# %%
salaries.sort_values(by = ['job_title', 'salary_in_usd'], ascending=[True, False], inplace= True)

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.loc[11/06/2022]
# Out:
#   Cell In[20], line 1
#     eth.loc[11/06/2022]
#                ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
eth.loc[['25/12/2021', '25/12/2022', '25/12/2023'], ['Price', 'High']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 eth.loc[['25/12/2021', '25/12/2022', '25/12/2023'], ['Price', 'High']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._multi_take(self, tup)
#    1310 """
#    1311 Create the indexers for the passed tuple of keys, and
#    1312 executes the take operation. This allows the take operation to be
#    (...)
#    1323 values: same type as the object being indexed
#    1324 """
#    1325 # GH 836
#    1326 d = {
# -> 1327     axis: self._get_listlike_indexer(key, axis)
#    1328     for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1329 }
#    1330 return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1558, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1555 ax = self.obj._get_axis(axis)
#    1556 axis_name = self.obj._get_axis_name(axis)
# -> 1558 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1560 return keyarr, indexer
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['25/12/2021', '25/12/2022', '25/12/2023'], dtype='object')] are in the [index]"

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 2543       2023               SE              FT
# 3357       2023               SE              FT
# 3697       2023               SE              FT
# 3895       2023               SE              FT
# 431        2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 5282       2020               EX              FT
# 3505       2020               SE              FT
# 8690       2021               SE              CT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2543                     AI Architect  330000             USD         330000
# 3357                     AI Architect  330000             USD         330000
# 3697                     AI Architect  330000             USD         330000
# 3895                     AI Architect  330000             USD         330000
# 431                      AI Architect  305100             USD         305100
# ...                               ...     ...             ...            ...
# 1672               Staff Data Analyst   60000             CAD          44753
# 5282               Staff Data Analyst   15000             USD          15000
# 3505             Staff Data Scientist  164000             USD         164000
# 8690             Staff Data Scientist  105000             USD         105000
# 3504  Staff Machine Learning Engineer  185000             USD         185000
#
#      employee_residence  remote_ratio company_location company_size
# 2543                 US             0               US            M
# 3357                 US             0               US            M
# 3697                 US             0               US            M
# 3895                 US             0               US            M
# 431                  US           100               US            M
# ...                 ...           ...              ...          ...
# 1672                 CA            50               CA            L
# 5282                 NG             0               CA            M
# 3505                 US            50               US            M
# 8690                 US           100               US            M
# 3504                 US            50               US            M
#
# [8805 rows x 11 columns]

# %%
salaries['salary_in_usd'].value_counts()
# Out:
# salary_in_usd
# 150000    188
# 130000    179
# 160000    174
# 100000    157
# 120000    154
#          ...
# 102544      1
# 41809       1
# 16455       1
# 450000      1
# 374000      1
# Name: count, Length: 1768, dtype: int64

# %%
salaries['salary_in_usd'].value_counts().loc[90000]
# Out:
# np.int64(80)

# %%
world = world.set_index('Country or region').sort_values(by='Country or region')

# %%
world
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Afghanistan                 154  2019  3.203           0.350           0.517
# Afghanistan                 145  2018  3.632           0.332           0.537
# Albania                     112  2018  4.586           0.916           0.817
# Albania                     107  2019  4.719           0.947           0.848
# Algeria                      84  2018  5.295           0.979           1.154
# ...                         ...   ...    ...             ...             ...
# Yemen                       152  2018  3.355           0.442           1.073
# Zambia                      138  2019  4.107           0.578           1.058
# Zambia                      125  2018  4.377           0.562           1.047
# Zimbabwe                    146  2019  3.663           0.366           1.114
# Zimbabwe                    144  2018  3.692           0.357           1.094
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Afghanistan                          0.361                         0.000
# Afghanistan                          0.255                         0.085
# Albania                              0.790                         0.419
# Albania                              0.874                         0.383
# Algeria                              0.687                         0.077
# ...                                    ...                           ...
# Yemen                                0.343                         0.244
# Zambia                               0.426                         0.431
# Zambia                               0.295                         0.503
# Zimbabwe                             0.433                         0.361
# Zimbabwe                             0.248                         0.406
#
#                    Generosity  Perceptions of corruption
# Country or region
# Afghanistan             0.158                      0.025
# Afghanistan             0.191                      0.036
# Albania                 0.149                      0.032
# Albania                 0.178                      0.027
# Algeria                 0.055                      0.135
# ...                       ...                        ...
# Yemen                   0.083                      0.064
# Zambia                  0.247                      0.087
# Zambia                  0.221                      0.082
# Zimbabwe                0.151                      0.089
# Zimbabwe                0.132                      0.099
#
# [312 rows x 9 columns]

# %%
world.loc['Ireland']
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Ireland                      16  2019  7.021           1.499           1.553
# Ireland                      14  2018  6.977           1.448           1.583
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Ireland                              0.999                         0.516
# Ireland                              0.876                         0.614
#
#                    Generosity  Perceptions of corruption
# Country or region
# Ireland                 0.298                      0.310
# Ireland                 0.307                      0.306

# %%
world = world.reset_index()

# %%
world
# Out:
#      index Country or region  Overall rank  Year  Score  GDP per capita  \
# 0        0       Afghanistan           154  2019  3.203           0.350
# 1        1       Afghanistan           145  2018  3.632           0.332
# 2        2           Albania           112  2018  4.586           0.916
# 3        3           Albania           107  2019  4.719           0.947
# 4        4           Algeria            84  2018  5.295           0.979
# ..     ...               ...           ...   ...    ...             ...
# 307    307             Yemen           152  2018  3.355           0.442
# 308    308            Zambia           138  2019  4.107           0.578
# 309    309            Zambia           125  2018  4.377           0.562
# 310    310          Zimbabwe           146  2019  3.663           0.366
# 311    311          Zimbabwe           144  2018  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.517                    0.361                         0.000
# 1             0.537                    0.255                         0.085
# 2             0.817                    0.790                         0.419
# 3             0.848                    0.874                         0.383
# 4             1.154                    0.687                         0.077
# ..              ...                      ...                           ...
# 307           1.073                    0.343                         0.244
# 308           1.058                    0.426                         0.431
# 309           1.047                    0.295                         0.503
# 310           1.114                    0.433                         0.361
# 311           1.094                    0.248                         0.406
#
#      Generosity  Perceptions of corruption
# 0         0.158                      0.025
# 1         0.191                      0.036
# 2         0.149                      0.032
# 3         0.178                      0.027
# 4         0.055                      0.135
# ..          ...                        ...
# 307       0.083                      0.064
# 308       0.247                      0.087
# 309       0.221                      0.082
# 310       0.151                      0.089
# 311       0.132                      0.099
#
# [312 rows x 11 columns]

# %%
world
# Out:
#      index Country or region  Overall rank  Year  Score  GDP per capita  \
# 0        0       Afghanistan           154  2019  3.203           0.350
# 1        1       Afghanistan           145  2018  3.632           0.332
# 2        2           Albania           112  2018  4.586           0.916
# 3        3           Albania           107  2019  4.719           0.947
# 4        4           Algeria            84  2018  5.295           0.979
# ..     ...               ...           ...   ...    ...             ...
# 307    307             Yemen           152  2018  3.355           0.442
# 308    308            Zambia           138  2019  4.107           0.578
# 309    309            Zambia           125  2018  4.377           0.562
# 310    310          Zimbabwe           146  2019  3.663           0.366
# 311    311          Zimbabwe           144  2018  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.517                    0.361                         0.000
# 1             0.537                    0.255                         0.085
# 2             0.817                    0.790                         0.419
# 3             0.848                    0.874                         0.383
# 4             1.154                    0.687                         0.077
# ..              ...                      ...                           ...
# 307           1.073                    0.343                         0.244
# 308           1.058                    0.426                         0.431
# 309           1.047                    0.295                         0.503
# 310           1.114                    0.433                         0.361
# 311           1.094                    0.248                         0.406
#
#      Generosity  Perceptions of corruption
# 0         0.158                      0.025
# 1         0.191                      0.036
# 2         0.149                      0.032
# 3         0.178                      0.027
# 4         0.055                      0.135
# ..          ...                        ...
# 307       0.083                      0.064
# 308       0.247                      0.087
# 309       0.221                      0.082
# 310       0.151                      0.089
# 311       0.132                      0.099
#
# [312 rows x 11 columns]

# %%
top_10_happy = world.set_index('Overall rank').sort_index().loc[1:10]

# %%
top_10_happy
# Out:
#               index Country or region  Year  Score  GDP per capita  \
# Overall rank
# 1                87           Finland  2018  7.632           1.305
# 1                88           Finland  2019  7.769           1.340
# 2                73           Denmark  2019  7.600           1.383
# 2               211            Norway  2018  7.594           1.456
# 3               210            Norway  2019  7.554           1.488
# 3                74           Denmark  2018  7.555           1.351
# 4               114           Iceland  2019  7.494           1.380
# 4               115           Iceland  2018  7.495           1.343
# 5               198       Netherlands  2019  7.488           1.396
# 5               266       Switzerland  2018  7.487           1.420
# 6               267       Switzerland  2019  7.480           1.452
# 6               197       Netherlands  2018  7.441           1.361
# 7                48            Canada  2018  7.328           1.330
# 7               264            Sweden  2019  7.343           1.387
# 8               199       New Zealand  2019  7.307           1.303
# 8               200       New Zealand  2018  7.324           1.268
# 9               265            Sweden  2018  7.314           1.355
# 9                49            Canada  2019  7.278           1.365
# 10               14           Austria  2019  7.246           1.376
# 10               11         Australia  2018  7.272           1.340
#
#               Social support  Healthy life expectancy  \
# Overall rank
# 1                      1.592                    0.874
# 1                      1.587                    0.986
# 2                      1.573                    0.996
# 2                      1.582                    0.861
# 3                      1.582                    1.028
# 3                      1.590                    0.868
# 4                      1.624                    1.026
# 4                      1.644                    0.914
# 5                      1.522                    0.999
# 5                      1.549                    0.927
# 6                      1.526                    1.052
# 6                      1.488                    0.878
# 7                      1.532                    0.896
# 7                      1.487                    1.009
# 8                      1.557                    1.026
# 8                      1.601                    0.876
# 9                      1.501                    0.913
# 9                      1.505                    1.039
# 10                     1.475                    1.016
# 10                     1.573                    0.910
#
#               Freedom to make life choices  Generosity  \
# Overall rank
# 1                                    0.681       0.202
# 1                                    0.596       0.153
# 2                                    0.592       0.252
# 2                                    0.686       0.286
# 3                                    0.603       0.271
# 3                                    0.683       0.284
# 4                                    0.591       0.354
# 4                                    0.677       0.353
# 5                                    0.557       0.322
# 5                                    0.660       0.256
# 6                                    0.572       0.263
# 6                                    0.638       0.333
# 7                                    0.653       0.321
# 7                                    0.574       0.267
# 8                                    0.585       0.330
# 8                                    0.669       0.365
# 9                                    0.659       0.285
# 9                                    0.584       0.285
# 10                                   0.532       0.244
# 10                                   0.647       0.361
#
#               Perceptions of corruption
# Overall rank
# 1                                 0.393
# 1                                 0.393
# 2                                 0.410
# 2                                 0.340
# 3                                 0.341
# 3                                 0.408
# 4                                 0.118
# 4                                 0.138
# 5                                 0.298
# 5                                 0.357
# 6                                 0.343
# 6                                 0.295
# 7                                 0.291
# 7                                 0.373
# 8                                 0.380
# 8                                 0.389
# 9                                 0.383
# 9                                 0.308
# 10                                0.226
# 10                                0.302

# %% [markdown]
# From Dataframes to Plots - converting Series to DataFrames

# %%
salaries['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                           2062
# Data Scientist                          1852
# Data Analyst                            1322
# Machine Learning Engineer                908
# Applied Scientist                        258
#                                         ...
# Machine Learning Operations Engineer       1
# Power BI Developer                         1
# Principal Data Architect                   1
# Sales Data Analyst                         1
# Staff Machine Learning Engineer            1
# Name: count, Length: 124, dtype: int64

# %%
top_20_jobs = pd.DataFrame(salaries['job_title'].value_counts()).head(20)

# %%
top_20_jobs
# Out:
#                                 count
# job_title
# Data Engineer                    2062
# Data Scientist                   1852
# Data Analyst                     1322
# Machine Learning Engineer         908
# Applied Scientist                 258
# Research Scientist                245
# Analytics Engineer                241
# Data Architect                    199
# Business Intelligence Engineer    134
# Research Engineer                 133
# Data Manager                      130
# ML Engineer                       100
# Data Science Manager               92
# Machine Learning Scientist         70
# BI Developer                       50
# Business Intelligence Analyst      48
# Data Specialist                    40
# Data Science Consultant            40
# Data Analytics Manager             39
# Decision Scientist                 38

# %%
top_20_jobs.sort_values(by='count').plot(kind='barh', color='skyblue')
# Out:
# <Axes: ylabel='job_title'>

# %%
salaries['experience_level'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
