# %%
import pandas as pd
import matplotlib as plt
world = pd.read_csv('Data for Python Course/2018-2019 Happiness.csv') # Importing world happiness dataset
airbnb = pd.read_csv('Data for Python Course/airbnb.csv')
salaries = pd.read_csv('Data for Python Course/salaries.csv')
sales = pd.read_csv('Data for Python Course/web_sales.csv')
eth = pd.read_csv('Ethereum Historical Data.csv', index_col = 0)

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1502 entries, 10/02/2024 to 1/01/2020
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Coin      1502 non-null   object
#  1   Price     1502 non-null   float64
#  2   Open      1502 non-null   float64
#  3   High      1502 non-null   float64
#  4   Low       1502 non-null   float64
#  5   Vol.      1502 non-null   object
#  6   Change %  1502 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 93.9+ KB

# %%
eth.index = pd.to_datetime(eth.index, format='%d/%m/%Y')

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 2024-02-10  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 2024-02-09  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2024-02-08  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 2024-02-07  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 2024-02-06  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 2020-01-05  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 2020-01-04  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 2020-01-03  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2020-01-02  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 2020-01-01  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.index
# Out:
# DatetimeIndex(['2024-02-10', '2024-02-09', '2024-02-08', '2024-02-07',
#                '2024-02-06', '2024-02-05', '2024-02-04', '2024-02-03',
#                '2024-02-02', '2024-02-01',
#                ...
#                '2020-01-10', '2020-01-09', '2020-01-08', '2020-01-07',
#                '2020-01-06', '2020-01-05', '2020-01-04', '2020-01-03',
#                '2020-01-02', '2020-01-01'],
#               dtype='datetime64[ns]', name='Date', length=1502, freq=None)

# %%
eth.sort_index(ascending = False)
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 2024-02-10  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 2024-02-09  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2024-02-08  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 2024-02-07  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 2024-02-06  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 2020-01-05  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 2020-01-04  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 2020-01-03  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2020-01-02  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 2020-01-01  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
airbnb['Host Since'] = pd.to_datetime(airbnb['Host Since'])
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_17400\4085603669.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   airbnb['Host Since'] = pd.to_datetime(airbnb['Host Since'])

# %%
airbnb.sort_values(by='Host Since')
# Out:
#         Host Id Host Since                                 Name Neighbourhood  \
# 3           500 2008-06-26   Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500 2008-06-26             Trendy Times Square Loft     Manhattan
# 5          1039 2008-07-25   Big Greenpoint 1BD w/ Skyline View      Brooklyn
# 6          1783 2008-08-12                         Amazing Also     Manhattan
# 7          2078 2008-08-15  Colorful, quiet, & near the subway!      Brooklyn
# ...         ...        ...                                  ...           ...
# 30469  43018396 2015-08-31   Cute East Village Studio Sept 8-16     Manhattan
# 30477  42999189 2015-08-31     Huge Beautiful Bedroom - Astoria        Queens
# 0       5162530        NaT      1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899        NaT      Sunny, Private room in Bushwick      Brooklyn
# 2      39608626        NaT                 Sunny Room in Harlem     Manhattan
#
# ...

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 2024-02-10  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 2024-02-09  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2024-02-08  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 2024-02-07  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 2024-02-06  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 2020-01-05  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 2020-01-04  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 2020-01-03  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2020-01-02  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 2020-01-01  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1502 entries, 2024-02-10 to 2020-01-01
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Coin      1502 non-null   object
#  1   Price     1502 non-null   float64
#  2   Open      1502 non-null   float64
#  3   High      1502 non-null   float64
#  4   Low       1502 non-null   float64
#  5   Vol.      1502 non-null   object
#  6   Change %  1502 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 93.9+ KB

# %%
eth['Change %'] = eth['Change %'].replace('%', '', regex= True)

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 2024-02-10  ETH  2508.31  2486.24  2514.83  2483.50  504.80K     0.89
# 2024-02-09  ETH  2486.24  2419.56  2522.96  2419.16  540.92K     2.76
# 2024-02-08  ETH  2419.56  2424.66  2461.00  2412.01  350.33K    -0.21
# 2024-02-07  ETH  2424.64  2372.65  2443.71  2354.46  355.40K     2.19
# 2024-02-06  ETH  2372.65  2301.83  2390.53  2299.24  381.23K     3.08
# ...         ...      ...      ...      ...      ...      ...      ...
# 2020-01-05  ETH   135.59   134.32   138.33   134.32   12.19M     0.94
# 2020-01-04  ETH   134.33   134.30   135.57   132.76   11.16M     0.04
# 2020-01-03  ETH   134.27   127.19   134.86   126.05   15.67M     5.56
# 2020-01-02  ETH   127.19   130.75   130.77   126.74   11.45M    -2.72
# 2020-01-01  ETH   130.75   129.21   132.97   128.81   10.35M     1.19
#
# [1502 rows x 7 columns]

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
sales['product_subcategory'] = sales['product_subcategory'].replace('Caps', 'Hats')

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Hats      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Hats      20140128
#
# ...

# %%
sales['SalesTerritoryRegion'] = sales['SalesTerritoryRegion'].replace(['Northwest', 'Southwest'], ['West USA', 'West USA'])

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Hats      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Hats      20140128
#
# ...

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 2024-02-10  ETH  2508.31  2486.24  2514.83  2483.50  504.80K     0.89
# 2024-02-09  ETH  2486.24  2419.56  2522.96  2419.16  540.92K     2.76
# 2024-02-08  ETH  2419.56  2424.66  2461.00  2412.01  350.33K    -0.21
# 2024-02-07  ETH  2424.64  2372.65  2443.71  2354.46  355.40K     2.19
# 2024-02-06  ETH  2372.65  2301.83  2390.53  2299.24  381.23K     3.08
# ...         ...      ...      ...      ...      ...      ...      ...
# 2020-01-05  ETH   135.59   134.32   138.33   134.32   12.19M     0.94
# 2020-01-04  ETH   134.33   134.30   135.57   132.76   11.16M     0.04
# 2020-01-03  ETH   134.27   127.19   134.86   126.05   15.67M     5.56
# 2020-01-02  ETH   127.19   130.75   130.77   126.74   11.45M    -2.72
# 2020-01-01  ETH   130.75   129.21   132.97   128.81   10.35M     1.19
#
# [1502 rows x 7 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1502 entries, 2024-02-10 to 2020-01-01
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Coin      1502 non-null   object
#  1   Price     1502 non-null   float64
#  2   Open      1502 non-null   float64
#  3   High      1502 non-null   float64
#  4   Low       1502 non-null   float64
#  5   Vol.      1502 non-null   object
#  6   Change %  1502 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 93.9+ KB

# %%
eth['Change %'] = eth['Change %'].astype('float') # Changing the data type on column 'Change %' from an obj to a decimal number(float)

# %%
eth.dtypes
# Out:
# Coin         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.         object
# Change %    float64
# dtype: object

# %%
eth[eth['Change %'] == 25.96]
# Out:
#            Coin    Price    Open    High      Low   Vol.  Change %
# Date
# 2021-05-24  ETH  2646.79  2101.3  2667.2  2080.87  3.24M     25.96

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             60398 non-null  int64
#  1   product                60398 non-null  object
#  2   product_subcategory    60398 non-null  object
#  3   OrderDateKey           60398 non-null  int64
#  4   CalendarYear           60398 non-null  int64
#  5   SalesTerritoryRegion   60398 non-null  object
#  6   SalesTerritoryCountry  60398 non-null  object
#  7   SalesOrderNumber       60398 non-null  object
#  8   SalesAmount            60398 non-null  float64
#  9   TaxAmt                 60398 non-null  float64
#  10  Freight                60398 non-null  float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 5.1+ MB

# %%
sales['OrderDateKey'] = pd.to_datetime(sales['OrderDateKey'], format='%Y%m%d')

# %%
sales
# Out:
#        ProductKey                  product product_subcategory OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes   2010-12-29
# 1             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# 2             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# 3             336       Road-650 Black, 62          Road Bikes   2010-12-29
# 4             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# ...           ...                      ...                 ...          ...
# 60393         485    Fender Set - Mountain             Fenders   2014-01-28
# 60394         225             AWC Logo Cap                Hats   2014-01-28
# 60395         485    Fender Set - Mountain             Fenders   2014-01-28
# 60396         486   All-Purpose Bike Stand         Bike Stands   2014-01-28
# 60397         225             AWC Logo Cap                Hats   2014-01-28
#
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60398 entries, 0 to 60397
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             60398 non-null  int64
#  1   product                60398 non-null  object
#  2   product_subcategory    60398 non-null  object
#  3   OrderDateKey           60398 non-null  datetime64[ns]
#  4   CalendarYear           60398 non-null  int64
#  5   SalesTerritoryRegion   60398 non-null  object
#  6   SalesTerritoryCountry  60398 non-null  object
#  7   SalesOrderNumber       60398 non-null  object
#  8   SalesAmount            60398 non-null  float64
#  9   TaxAmt                 60398 non-null  float64
#  10  Freight                60398 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 5.1+ MB

# %%
sales['month'] = sales['OrderDateKey'].dt.month

# %%
sales['OrderDateKey'].dt.day
# Out:
# 0        29
# 1        29
# 2        29
# 3        29
# 4        29
#          ..
# 60393    28
# 60394    28
# 60395    28
# 60396    28
# 60397    28
# Name: OrderDateKey, Length: 60398, dtype: int32

# %%
sales
# Out:
#        ProductKey                  product product_subcategory OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes   2010-12-29
# 1             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# 2             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# 3             336       Road-650 Black, 62          Road Bikes   2010-12-29
# 4             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# ...           ...                      ...                 ...          ...
# 60393         485    Fender Set - Mountain             Fenders   2014-01-28
# 60394         225             AWC Logo Cap                Hats   2014-01-28
# 60395         485    Fender Set - Mountain             Fenders   2014-01-28
# 60396         486   All-Purpose Bike Stand         Bike Stands   2014-01-28
# 60397         225             AWC Logo Cap                Hats   2014-01-28
#
# ...

# %%
sales['month'].value_counts()  # Which month produced the most orders
# Out:
# month
# 12    6239
# 10    5834
# 11    5756
# 6     5573
# 8     5352
# 7     5105
# 9     5070
# 5     4780
# 3     4449
# 4     4355
# 1     4028
# 2     3857
# Name: count, dtype: int64

# %%
sales['month_end_flag'] = sales['OrderDateKey'].dt.is_month_end

# %%
sales.dtypes
# Out:
# ProductKey                        int64
# product                          object
# product_subcategory              object
# OrderDateKey             datetime64[ns]
# CalendarYear                      int64
# SalesTerritoryRegion             object
# SalesTerritoryCountry            object
# SalesOrderNumber                 object
# SalesAmount                     float64
# TaxAmt                          float64
# Freight                         float64
# month                             int32
# month_end_flag                     bool
# dtype: object

# %%
sales['month_end_flag'] = sales['month_end_flag'].replace([False, True], [0, 1])
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_17400\3182961963.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sales['month_end_flag'] = sales['month_end_flag'].replace([False, True], [0, 1])

# %%
sales
# Out:
#        ProductKey                  product product_subcategory OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes   2010-12-29
# 1             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# 2             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# 3             336       Road-650 Black, 62          Road Bikes   2010-12-29
# 4             346  Mountain-100 Silver, 44      Mountain Bikes   2010-12-29
# ...           ...                      ...                 ...          ...
# 60393         485    Fender Set - Mountain             Fenders   2014-01-28
# 60394         225             AWC Logo Cap                Hats   2014-01-28
# 60395         485    Fender Set - Mountain             Fenders   2014-01-28
# 60396         486   All-Purpose Bike Stand         Bike Stands   2014-01-28
# 60397         225             AWC Logo Cap                Hats   2014-01-28
#
# ...

# %%
sales[sales['month_end_flag'] == 1]
# Out:
#        ProductKey                  product product_subcategory OrderDateKey  \
# 9             312         Road-150 Red, 48          Road Bikes   2010-12-31
# 10            312         Road-150 Red, 48          Road Bikes   2010-12-31
# 11            330         Road-650 Red, 52          Road Bikes   2010-12-31
# 12            313         Road-150 Red, 52          Road Bikes   2010-12-31
# 13            314         Road-150 Red, 56          Road Bikes   2010-12-31
# ...           ...                      ...                 ...          ...
# 58423         225             AWC Logo Cap                Hats   2013-12-31
# 58424         537         HL Mountain Tire     Tires and Tubes   2013-12-31
# 58425         528       Mountain Tire Tube     Tires and Tubes   2013-12-31
# 58426         217  Sport-100 Helmet, Black             Helmets   2013-12-31
# 58427         225             AWC Logo Cap                Hats   2013-12-31
#
# ...

# %%
sales.groupby('CalendarYear')['SalesAmount'].mean()
# Out:
# CalendarYear
# 2010    3101.502600
# 2011    3192.926863
# 2012    1719.895553
# 2013     309.682588
# 2014      23.195289
# Name: SalesAmount, dtype: float64

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries[salaries['job_title'] == 'Data Scientist']['salary_in_usd'].mean()
# Out:
# np.float64(156074.3612311015)

# %%
salaries.groupby('job_title')['salary_in_usd'].mean().sort_values(ascending = False)
# Out:
# job_title
# Business Intelligence Consultant    615201.000
# Analytics Engineering Manager       399880.000
# Data Science Tech Lead              375000.000
# Managing Director Data Science      300000.000
# AWS Data Architect                  258000.000
#                                        ...
# Machine Learning Specialist          55000.000
# Data DevOps Engineer                 53984.000
# Insight Analyst                      47673.875
# Compliance Data Analyst              45000.000
# Principal Data Architect             38154.000
# Name: salary_in_usd, Length: 124, dtype: float64

# %%
salaries.groupby('job_title')['salary_in_usd'].max().sort_values(ascending = False)
# Out:
# job_title
# Business Intelligence Consultant        615201
# Research Scientist                      450000
# Data Analyst                            430967
# Analytics Engineer                      430640
# Applied Machine Learning Scientist      423000
#                                          ...
# Compliance Data Analyst                  60000
# Machine Learning Operations Engineer     60000
# Data DevOps Engineer                     53984
# Insight Analyst                          53984
# Principal Data Architect                 38154
# Name: salary_in_usd, Length: 124, dtype: int64

# %%
salaries.groupby(['job_title', 'company_location', 'experience_level'])['salary_in_usd'].mean().sort_values(ascending=False)
# Out:
# job_title                         company_location  experience_level
# Business Intelligence Consultant  IN                EN                  615201.0
# AI Scientist                      IL                SE                  417937.0
# Principal Data Scientist          US                EX                  416000.0
# Data Analytics Lead               US                SE                  405000.0
# Analytics Engineering Manager     GB                SE                  399880.0
#                                                                           ...
# Data Analyst                      PH                MI                   15680.0
#                                   ID                EN                   15000.0
# Business Intelligence Developer   GH                MI                   15000.0
# Staff Data Analyst                CA                EX                   15000.0
# Machine Learning Developer        TH                EN                   15000.0
# ...

# %% [markdown]
# Aggregation with .agg Method

# %%
salaries.groupby('job_title')['salary_in_usd'].agg(['mean', 'max', 'min']).sort_values(by= 'mean', ascending=False).head(25)
# Out:
#                                              mean     max     min
# job_title
# Business Intelligence Consultant    615201.000000  615201  615201
# Analytics Engineering Manager       399880.000000  399880  399880
# Data Science Tech Lead              375000.000000  375000  375000
# Managing Director Data Science      300000.000000  300000  300000
# AWS Data Architect                  258000.000000  258000  258000
# AI Architect                        250328.000000  330000  146900
# Cloud Data Architect                250000.000000  250000  250000
# Director of Data Science            221365.034483  375500   57786
# Head of Data                        209166.322581  329500   31520
# Data Infrastructure Engineer        201375.416667  385000  143000
# Data Science Director               201000.000000  212000  190000
# Head of Machine Learning            198103.000000  330000   76309
# Data Science Manager                195474.250000  328000   38915
# ...

# %%
salaries.groupby('job_title').agg(avg_salary=('salary_in_usd', 'mean'),
                                 min_salary=('salary_in_usd', 'min'),
                                 max_salary=('salary_in_usd', 'max'))
# Out:
#                                     avg_salary  min_salary  max_salary
# job_title
# AI Architect                     250328.000000      146900      330000
# AI Developer                     139916.705882       50000      275000
# AI Engineer                      175116.225806       21593      372000
# AI Programmer                     67382.333333       40000      120000
# AI Research Engineer              63481.600000       24322      150000
# ...                                        ...         ...         ...
# Sales Data Analyst                60000.000000       60000       60000
# Software Data Engineer           111627.666667       50000      210000
# Staff Data Analyst                79917.000000       15000      179998
# Staff Data Scientist             134500.000000      105000      164000
# Staff Machine Learning Engineer  185000.000000      185000      185000
#
# [124 rows x 3 columns]

# %%
salaries.groupby('job_title').agg({'salary_in_usd':['mean', 'max', 'min'], 'remote_ratio':['mean']})
# Out:
#                                  salary_in_usd                 remote_ratio
#                                           mean     max     min         mean
# job_title
# AI Architect                     250328.000000  330000  146900    33.333333
# AI Developer                     139916.705882  275000   50000    41.176471
# AI Engineer                      175116.225806  372000   21593    30.645161
# AI Programmer                     67382.333333  120000   40000    50.000000
# AI Research Engineer              63481.600000  150000   24322    80.000000
# ...                                        ...     ...     ...          ...
# Sales Data Analyst                60000.000000   60000   60000     0.000000
# Software Data Engineer           111627.666667  210000   50000    83.333333
# Staff Data Analyst                79917.000000  179998   15000    50.000000
# Staff Data Scientist             134500.000000  164000  105000    75.000000
# ...

# %%
work_year_avg_salary_with_experience= salaries.groupby(['work_year', 'experience_level'])['salary_in_usd'].mean().unstack()

# %%
work_year_avg_salary_with_experience
# Out:
# experience_level            EN             EX             MI             SE
# work_year
# 2020              69840.666667  179958.250000   91870.935484  138648.894737
# 2021              63463.065217  186128.000000   86818.390805  125989.746667
# 2022              80018.698276  188260.292683  102733.432961  148059.962148
# 2023              96016.143860  189511.070093  120579.427548  165579.532707

# %%
work_year_avg_salary_with_experience.stack()
# Out:
# work_year  experience_level
# 2020       EN                   69840.666667
#            EX                  179958.250000
#            MI                   91870.935484
#            SE                  138648.894737
# 2021       EN                   63463.065217
#            EX                  186128.000000
#            MI                   86818.390805
#            SE                  125989.746667
# 2022       EN                   80018.698276
#            EX                  188260.292683
#            MI                  102733.432961
#            SE                  148059.962148
# 2023       EN                   96016.143860
#            EX                  189511.070093
#            MI                  120579.427548
#            SE                  165579.532707
# dtype: float64

# %%
work_year_avg_salary_with_experience.plot()
# Out:
# <Axes: xlabel='work_year'>

# %%
work_year_avg_salary_with_experience.plot(kind='bar', figsize=(10,6 ))
# Out:
# <Axes: xlabel='work_year'>

# %%
bike_sales = sales[sales['product_subcategory'].isin(['Mountain Bikes', 'Road Bikes', 'Touring Bikes'])]
bike_sales.groupby(['product_subcategory', 'SalesTerritoryCountry'])['SalesAmount'].sum().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='product_subcategory'>
